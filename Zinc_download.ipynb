# %% [markdown]
# <a href="https://colab.research.google.com/github/ZackLiuzeyu/FeatureHunter/blob/master/Zinc_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare for downloading
#
# - The download script is generated on 10 Feb 2023

# %%
# !git clone https://github.com/quantaosun/Zinc-Million.git
# !cp /content/Zinc-Million/ZINC-downloader-3D-sdf.gz.wget .
# !cat ZINC-downloader-3D-sdf.gz.wget > download.sh
# Out:
# Cloning into 'Zinc-Million'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 73 (delta 37), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 2.52 MiB | 10.02 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# # Download

# %%
# !sh download.sh
# Out:
# mkdir: created directory 'CA'
# mkdir: created directory 'CA/AAML'
# --2025-12-19 07:18:22--  http://files.docking.org/3D/CA/AAML/CAAAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:22 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AAMM'
# --2025-12-19 07:18:22--  http://files.docking.org/3D/CA/AAMM/CAAAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AAMO'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AAMO/CAAAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AAMP'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AAMP/CAAAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AARL'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AARL/CAAARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AARM'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AARM/CAAARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AARO'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AARO/CAAARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/AARP'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/AARP/CAAARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABML'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/ABML/CAABML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABMM'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/ABMM/CAABMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:23 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABMO'
# --2025-12-19 07:18:23--  http://files.docking.org/3D/CA/ABMO/CAABMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABMP'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/ABMP/CAABMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABRL'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/ABRL/CAABRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABRM'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/ABRM/CAABRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABRO'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/ABRO/CAABRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/ABRP'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/ABRP/CAABRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BAMM'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/BAMM/CABAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BARL'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/BARL/CABARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BARM'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/BARM/CABARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:24 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BARO'
# --2025-12-19 07:18:24--  http://files.docking.org/3D/CA/BARO/CABARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BARP'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/BARP/CABARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BBMM'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/BBMM/CABBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/BBRM'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/BBRM/CABBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CAML'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CAML/CACAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CAMM'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CAMM/CACAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CAMO'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CAMO/CACAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CARL'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CARL/CACARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CARM'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CARM/CACARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:25 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CARO'
# --2025-12-19 07:18:25--  http://files.docking.org/3D/CA/CARO/CACARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CBML'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/CBML/CACBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CBMM'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/CBMM/CACBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CBRL'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/CBRL/CACBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/CBRM'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/CBRM/CACBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EAML'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/EAML/CAEAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EAMM'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/EAMM/CAEAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EAMO'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/EAMO/CAEAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EARL'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/EARL/CAEARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:26 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EARM'
# --2025-12-19 07:18:26--  http://files.docking.org/3D/CA/EARM/CAEARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EARO'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EARO/CAEARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EARP'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EARP/CAEARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBML'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBML/CAEBML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBMM'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBMM/CAEBMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBMO'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBMO/CAEBMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBMP'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBMP/CAEBMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBRL'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBRL/CAEBRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBRM'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBRM/CAEBRM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:27 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBRO'
# --2025-12-19 07:18:27--  http://files.docking.org/3D/CA/EBRO/CAEBRO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'CA/EBRP'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/CA/EBRP/CAEBRP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA'
# mkdir: created directory 'DA/AAML'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AAML/DAAAML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AAMM'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AAMM/DAAAMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AAMO'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AAMO/DAAAMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AAMP'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AAMP/DAAAMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AARL'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AARL/DAAARL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AARM'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AARM/DAAARM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AARO'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AARO/DAAARO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/AARP'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/AARP/DAAARP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:28 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/ABML'
# --2025-12-19 07:18:28--  http://files.docking.org/3D/DA/ABML/DAABML.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:29 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/ABMM'
# --2025-12-19 07:18:29--  http://files.docking.org/3D/DA/ABMM/DAABMM.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:29 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/ABMO'
# --2025-12-19 07:18:29--  http://files.docking.org/3D/DA/ABMO/DAABMO.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:29 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/ABMP'
# --2025-12-19 07:18:29--  http://files.docking.org/3D/DA/ABMP/DAABMP.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-12-19 07:18:29 ERROR 403: Forbidden.
#
# mkdir: created directory 'DA/ABRL'
# --2025-12-19 07:18:29--  http://files.docking.org/3D/DA/ABRL/DAABRL.xaa.sdf.gz
# Resolving files.docking.org (files.docking.org)... 169.230.75.4
# Connecting to files.docking.org (files.docking.org)|169.230.75.4|:80... connected.
# HTTP request sent, awaiting response... ^C

# %%
# !sed -i 's|http://|https://|g' download.sh

# %% [markdown]
# # Processing after download

# %%
#@title Write a bash for processing
com_file = open('1.sh','w')
com_file.write('''
#!/bin/bash

# 进入每个子文件夹
for dir in */; do
  cd "$dir"
  # 进入内部文件夹
  for inner_dir in */; do
    cd "$inner_dir"
    # 解压所有.gz文件
    for file in *.gz; do
      gunzip "$file"
    done
    # 复制所有解压后的文件到上层文件夹
    mv *.sdf ../../
    cd ../
  done
  cd ../
done

# 合并所有文件
cat *.sdf > all_zinc.sdf
''')
com_file.close()

# %%
#@title Run bash
# !sh 1.sh
# Out:
# gzip: CAAAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAAMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAAARP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABRM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABRO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAABRP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABARP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABBMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CABBRM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACAMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACBML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACBMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACBRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CACBRM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEAMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEARP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBRM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBRO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: CAEBRP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAAML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAAMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAAMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAAMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAARL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAARM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAARO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAAARP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAABML.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAABMM.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAABMO.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAABMP.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
#
# gzip: DAABRL.xaa.sdf.gz: unexpected end of file
# mv: cannot stat '*.sdf': No such file or directory
# 1.sh: 9: cd: can't cd to */
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# 1.sh: 6: cd: can't cd to sample_data/
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: config: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# gzip: *.gz: No such file or directory
# mv: cannot stat '*.sdf': No such file or directory
# cat: '*.sdf': No such file or directory
